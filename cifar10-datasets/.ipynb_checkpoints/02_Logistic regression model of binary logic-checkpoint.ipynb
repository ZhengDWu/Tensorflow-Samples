# %% [markdown]
# # Part2: 二分类逻辑斯蒂回归模型

# %%
import tensorflow as tf
import pickle
import numpy as np
import os

# the path of the cifar10 datasets 
# which is downloaded from the link of "https://www.cs.toronto.edu/~kriz/cifar.html" (Warning: we should download the python version)
CIFAR_DIR = "./cifar-10-batches-py" 
print(os.listdir(CIFAR_DIR))
# Out:
# ['batches.meta', 'data_batch_1', 'data_batch_2', 'data_batch_3', 'data_batch_4', 'data_batch_5', 'readme.html', 'test_batch']

# %%
def load_data(filename):
    # read data from data file
    with open(filename, 'rb') as f:
        data = pickle.load(f, encoding='bytes')
        return data[b'data'], data[b'labels']

class CifarData(object):
    def __init__(self, filenames, need_shuffle):
        all_data = []
        all_labels = []
        for filename in filenames:
            data, labels = load_data(filename)
            for item, label in zip(data, labels):
                if label in [0, 1]:
                    all_data.append(item)
                    all_labels.append(label)
        self._data = np.vstack(all_data) # 纵向合并 [10000, 3072]，每个像素点的大小是（0，255）
        # 将数据缩放到 （-1，1）之间
        # 255 / 127.5 - 1 = 1
        # 0 / 127.5 -1 = -1
        self._data = self._data / 127.5 -1 
        print(self._data.shape)
        self._labels = np.hstack(all_labels) # 横向合并 [10000,]
        self._num_examples = self._data.shape[0] # 10000
        self._need_shuffle = need_shuffle
        self._indicator = 0
        if self._need_shuffle:
            self._shuffle_data()
    
    def _shuffle_data(self):
        # 打乱顺序，用于 training set
        p = np.random.permutation(self._num_examples)
        self._data = self._data[p]
        self._labels = self._labels[p]
    
    def next_batch(self, batch_size):
        '''return batch_size examples as a batch'''
        end_indicator = self._indicator + batch_size
        if end_indicator > self._num_examples:
            if self._need_shuffle:
                # 训练集的情况，要 shuffle 一下
                self._shuffle_data()
                self._indicator = 0
                end_indicator = batch_size
            else:
                # 测试集的情况，不需要 shuffle
                self._indicator = 0
                end_indicator = batch_size

        if end_indicator > self._num_examples:
            raise Exception("batch size is larger than all examples")
        batch_data = self._data[self._indicator: end_indicator]
        batch_lables = self._labels[self._indicator: end_indicator]
        self._indicator = end_indicator
        return batch_data, batch_lables

train_filenames = [os.path.join(CIFAR_DIR, 'data_batch_%d' % i) for i in range(1, 6)]
test_filenames = [os.path.join(CIFAR_DIR, 'test_batch')]

train_data = CifarData(train_filenames, True)
test_data = CifarData(test_filenames, False)
# Out:
# (10000, 3072)
# (2000, 3072)

# %%
tf.reset_default_graph()

x = tf.placeholder(tf.float32, [None, 3072])
y = tf.placeholder(tf.int64, [None])

w = tf.get_variable('w', [x.get_shape()[-1], 1],
                    initializer=tf.random_normal_initializer(0, 1)) # weight which shape is (3072, 1)
b = tf.get_variable('b', [1],
                    initializer=tf.constant_initializer(0.0)) # bias which shape is (1, )

# [None, 3027] * [3027, 1] + [1, ] = [None, 1]
y_ = tf.matmul(x, w) + b

# [None, 1]
p_y_1 = tf.nn.sigmoid(y_)
# reshape the shape of y to [None, 1], in the meantime, change its type to float
y_reshaped = tf.reshape(y, (-1, 1))
y_reshaped_float = tf.cast(y_reshaped, tf.float32)

# f(x) = \bar{(y_reshaped - p_y_1)^{2}}
loss = tf.reduce_mean(tf.square(y_reshaped_float - p_y_1))

predict = p_y_1 > 0.5 # bool
# outputs: [1, 0, 1, 1, 0, 0, 1...]
correct_prediction = tf.equal(tf.cast(predict, tf.int64), y_reshaped)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float64))

with tf.name_scope('train_op'):
    train_op = tf.train.AdamOptimizer(1e-3).minimize(loss)

# %%
init = tf.global_variables_initializer()
# hyper-parameter setting
batch_size = 20
train_steps = 100000 # 训练集个数10000 / 20 （batch_size） = 500 step 训练完全部训练集，100000 / 500 = 200 次，每次都打乱
test_steps = 100     # 测试集个数2000 / 20（batch_size） = 100 step

with tf.Session() as sess:
    sess.run(init)
    for i in range(train_steps):
        batch_data, batch_lables = train_data.next_batch(batch_size)
        loss_val, acc_val, _ = sess.run(
            [loss, accuracy, train_op],
            feed_dict={
                x: batch_data,
                y: batch_lables}
        )
        if (i + 1) % 500 == 0:
            print("[Trian] Step: %d, loss: %4.5f, acc: %4.5f" % (i+1, loss_val, acc_val))
        if (i + 1) % 5000 == 0:
            all_test_acc_val = [] # 存储每个 batch 的准确率
            for j in range(test_steps):
                test_batch_data, test_batch_lables = test_data.next_batch(batch_size)
                test_acc_val = sess.run(
                    [accuracy],
                    feed_dict = {
                        x: test_batch_data,
                        y: test_batch_lables
                    })
                all_test_acc_val.append(test_acc_val)
            test_acc = np.mean(all_test_acc_val)
            print('[Test] Step: %d, acc: %4.5f' % (i + 1, test_acc))
# Out:
# [Trian] Step: 500, loss: 0.30485, acc: 0.65000
# [Trian] Step: 1000, loss: 0.08185, acc: 0.90000
# [Trian] Step: 1500, loss: 0.34801, acc: 0.65000
# [Trian] Step: 2000, loss: 0.19981, acc: 0.80000
# [Trian] Step: 2500, loss: 0.05152, acc: 0.95000
# [Trian] Step: 3000, loss: 0.19954, acc: 0.80000
# [Trian] Step: 3500, loss: 0.14784, acc: 0.85000
# [Trian] Step: 4000, loss: 0.15004, acc: 0.85000
# [Trian] Step: 4500, loss: 0.00788, acc: 1.00000
# [Trian] Step: 5000, loss: 0.29823, acc: 0.70000
# [Test] Step: 5000, acc: 0.79600
# [Trian] Step: 5500, loss: 0.19969, acc: 0.80000
# [Trian] Step: 6000, loss: 0.16297, acc: 0.85000
# [Trian] Step: 6500, loss: 0.15542, acc: 0.85000
# [Trian] Step: 7000, loss: 0.27094, acc: 0.70000
# [Trian] Step: 7500, loss: 0.15000, acc: 0.85000
# [Trian] Step: 8000, loss: 0.09964, acc: 0.90000
# [Trian] Step: 8500, loss: 0.07890, acc: 0.90000
# [Trian] Step: 9000, loss: 0.10307, acc: 0.90000
# [Trian] Step: 9500, loss: 0.05066, acc: 0.95000
# [Trian] Step: 10000, loss: 0.15047, acc: 0.85000
# [Test] Step: 10000, acc: 0.80550
# [Trian] Step: 10500, loss: 0.15000, acc: 0.85000
# [Trian] Step: 11000, loss: 0.04607, acc: 0.95000
# [Trian] Step: 11500, loss: 0.20034, acc: 0.80000
# [Trian] Step: 12000, loss: 0.22172, acc: 0.75000
# [Trian] Step: 12500, loss: 0.09877, acc: 0.90000
# [Trian] Step: 13000, loss: 0.14944, acc: 0.85000
# [Trian] Step: 13500, loss: 0.05002, acc: 0.95000
# [Trian] Step: 14000, loss: 0.07868, acc: 0.90000
# [Trian] Step: 14500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 15000, loss: 0.23448, acc: 0.75000
# [Test] Step: 15000, acc: 0.80850
# [Trian] Step: 15500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 16000, loss: 0.16648, acc: 0.80000
# [Trian] Step: 16500, loss: 0.01908, acc: 0.95000
# [Trian] Step: 17000, loss: 0.26011, acc: 0.70000
# [Trian] Step: 17500, loss: 0.15002, acc: 0.85000
# [Trian] Step: 18000, loss: 0.20000, acc: 0.80000
# [Trian] Step: 18500, loss: 0.20030, acc: 0.80000
# [Trian] Step: 19000, loss: 0.10000, acc: 0.90000
# [Trian] Step: 19500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 20000, loss: 0.20264, acc: 0.80000
# [Test] Step: 20000, acc: 0.81100
# [Trian] Step: 20500, loss: 0.15316, acc: 0.85000
# [Trian] Step: 21000, loss: 0.25000, acc: 0.75000
# [Trian] Step: 21500, loss: 0.10107, acc: 0.90000
# [Trian] Step: 22000, loss: 0.05791, acc: 0.95000
# [Trian] Step: 22500, loss: 0.23870, acc: 0.75000
# [Trian] Step: 23000, loss: 0.06140, acc: 0.95000
# [Trian] Step: 23500, loss: 0.37174, acc: 0.60000
# [Trian] Step: 24000, loss: 0.25000, acc: 0.75000
# [Trian] Step: 24500, loss: 0.09553, acc: 0.90000
# [Trian] Step: 25000, loss: 0.29984, acc: 0.70000
# [Test] Step: 25000, acc: 0.81100
# [Trian] Step: 25500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 26000, loss: 0.24995, acc: 0.75000
# [Trian] Step: 26500, loss: 0.30000, acc: 0.70000
# [Trian] Step: 27000, loss: 0.13868, acc: 0.85000
# [Trian] Step: 27500, loss: 0.15525, acc: 0.85000
# [Trian] Step: 28000, loss: 0.18010, acc: 0.80000
# [Trian] Step: 28500, loss: 0.15553, acc: 0.85000
# [Trian] Step: 29000, loss: 0.12019, acc: 0.85000
# [Trian] Step: 29500, loss: 0.10609, acc: 0.90000
# [Trian] Step: 30000, loss: 0.22254, acc: 0.75000
# [Test] Step: 30000, acc: 0.81400
# [Trian] Step: 30500, loss: 0.34999, acc: 0.65000
# [Trian] Step: 31000, loss: 0.14837, acc: 0.85000
# [Trian] Step: 31500, loss: 0.18792, acc: 0.75000
# [Trian] Step: 32000, loss: 0.15739, acc: 0.85000
# [Trian] Step: 32500, loss: 0.09999, acc: 0.90000
# [Trian] Step: 33000, loss: 0.29547, acc: 0.70000
# [Trian] Step: 33500, loss: 0.20400, acc: 0.80000
# [Trian] Step: 34000, loss: 0.15216, acc: 0.85000
# [Trian] Step: 34500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 35000, loss: 0.19015, acc: 0.75000
# [Test] Step: 35000, acc: 0.81500
# [Trian] Step: 35500, loss: 0.05000, acc: 0.95000
# [Trian] Step: 36000, loss: 0.22512, acc: 0.75000
# [Trian] Step: 36500, loss: 0.05275, acc: 0.95000
# [Trian] Step: 37000, loss: 0.06892, acc: 0.90000
# [Trian] Step: 37500, loss: 0.05034, acc: 0.95000
# [Trian] Step: 38000, loss: 0.15309, acc: 0.85000
# [Trian] Step: 38500, loss: 0.15026, acc: 0.85000
# [Trian] Step: 39000, loss: 0.05001, acc: 0.95000
# [Trian] Step: 39500, loss: 0.24986, acc: 0.75000
# [Trian] Step: 40000, loss: 0.31826, acc: 0.65000
# [Test] Step: 40000, acc: 0.81500
# [Trian] Step: 40500, loss: 0.24795, acc: 0.75000
# [Trian] Step: 41000, loss: 0.21639, acc: 0.80000
# [Trian] Step: 41500, loss: 0.15000, acc: 0.85000
# [Trian] Step: 42000, loss: 0.25000, acc: 0.75000
# [Trian] Step: 42500, loss: 0.10056, acc: 0.90000
# [Trian] Step: 43000, loss: 0.24944, acc: 0.75000
# [Trian] Step: 43500, loss: 0.34999, acc: 0.65000
# [Trian] Step: 44000, loss: 0.15046, acc: 0.85000
# [Trian] Step: 44500, loss: 0.15000, acc: 0.85000
# [Trian] Step: 45000, loss: 0.45408, acc: 0.55000
# [Test] Step: 45000, acc: 0.81700
# [Trian] Step: 45500, loss: 0.15016, acc: 0.85000
# [Trian] Step: 46000, loss: 0.10950, acc: 0.90000
# [Trian] Step: 46500, loss: 0.26496, acc: 0.70000
# [Trian] Step: 47000, loss: 0.04999, acc: 0.95000
# [Trian] Step: 47500, loss: 0.31503, acc: 0.65000
# [Trian] Step: 48000, loss: 0.00000, acc: 1.00000
# [Trian] Step: 48500, loss: 0.14998, acc: 0.85000
# [Trian] Step: 49000, loss: 0.14999, acc: 0.85000
# [Trian] Step: 49500, loss: 0.20032, acc: 0.80000
# [Trian] Step: 50000, loss: 0.25400, acc: 0.75000
# [Test] Step: 50000, acc: 0.81600
# [Trian] Step: 50500, loss: 0.20015, acc: 0.80000
# [Trian] Step: 51000, loss: 0.10074, acc: 0.90000
# [Trian] Step: 51500, loss: 0.09415, acc: 0.90000
# [Trian] Step: 52000, loss: 0.39670, acc: 0.60000
# [Trian] Step: 52500, loss: 0.17168, acc: 0.80000
# [Trian] Step: 53000, loss: 0.05833, acc: 0.95000
# [Trian] Step: 53500, loss: 0.15054, acc: 0.85000
# [Trian] Step: 54000, loss: 0.10819, acc: 0.90000
# [Trian] Step: 54500, loss: 0.17725, acc: 0.80000
# [Trian] Step: 55000, loss: 0.29999, acc: 0.70000
# [Test] Step: 55000, acc: 0.81650
# [Trian] Step: 55500, loss: 0.10016, acc: 0.90000
# [Trian] Step: 56000, loss: 0.09862, acc: 0.90000
# [Trian] Step: 56500, loss: 0.40302, acc: 0.60000
# [Trian] Step: 57000, loss: 0.20000, acc: 0.80000
# [Trian] Step: 57500, loss: 0.34951, acc: 0.65000
# [Trian] Step: 58000, loss: 0.09990, acc: 0.90000
# [Trian] Step: 58500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 59000, loss: 0.34999, acc: 0.65000
# [Trian] Step: 59500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 60000, loss: 0.00456, acc: 1.00000
# [Test] Step: 60000, acc: 0.81800
# [Trian] Step: 60500, loss: 0.29998, acc: 0.70000
# [Trian] Step: 61000, loss: 0.24870, acc: 0.75000
# [Trian] Step: 61500, loss: 0.25507, acc: 0.75000
# [Trian] Step: 62000, loss: 0.10010, acc: 0.90000
# [Trian] Step: 62500, loss: 0.05551, acc: 0.95000
# [Trian] Step: 63000, loss: 0.09946, acc: 0.85000
# [Trian] Step: 63500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 64000, loss: 0.20000, acc: 0.80000
# [Trian] Step: 64500, loss: 0.05000, acc: 0.95000
# [Trian] Step: 65000, loss: 0.10002, acc: 0.90000
# [Test] Step: 65000, acc: 0.82000
# [Trian] Step: 65500, loss: 0.26069, acc: 0.75000
# [Trian] Step: 66000, loss: 0.15735, acc: 0.85000
# [Trian] Step: 66500, loss: 0.00289, acc: 1.00000
# [Trian] Step: 67000, loss: 0.00013, acc: 1.00000
# [Trian] Step: 67500, loss: 0.05021, acc: 0.95000
# [Trian] Step: 68000, loss: 0.05106, acc: 0.95000
# [Trian] Step: 68500, loss: 0.10087, acc: 0.90000
# [Trian] Step: 69000, loss: 0.10056, acc: 0.90000
# [Trian] Step: 69500, loss: 0.20458, acc: 0.80000
# [Trian] Step: 70000, loss: 0.15001, acc: 0.85000
# [Test] Step: 70000, acc: 0.81800
# [Trian] Step: 70500, loss: 0.14968, acc: 0.85000
# [Trian] Step: 71000, loss: 0.06401, acc: 0.95000
# [Trian] Step: 71500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 72000, loss: 0.05047, acc: 0.95000
# [Trian] Step: 72500, loss: 0.05230, acc: 0.95000
# [Trian] Step: 73000, loss: 0.15035, acc: 0.85000
# [Trian] Step: 73500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 74000, loss: 0.11284, acc: 0.90000
# [Trian] Step: 74500, loss: 0.10000, acc: 0.90000
# [Trian] Step: 75000, loss: 0.14994, acc: 0.85000
# [Test] Step: 75000, acc: 0.81900
# [Trian] Step: 75500, loss: 0.19991, acc: 0.80000
# [Trian] Step: 76000, loss: 0.05000, acc: 0.95000
# [Trian] Step: 76500, loss: 0.30005, acc: 0.70000
# [Trian] Step: 77000, loss: 0.20012, acc: 0.80000
# [Trian] Step: 77500, loss: 0.22450, acc: 0.75000
# [Trian] Step: 78000, loss: 0.10000, acc: 0.90000
# [Trian] Step: 78500, loss: 0.10281, acc: 0.90000
# [Trian] Step: 79000, loss: 0.14995, acc: 0.85000
# [Trian] Step: 79500, loss: 0.10025, acc: 0.90000
# [Trian] Step: 80000, loss: 0.20000, acc: 0.80000
# [Test] Step: 80000, acc: 0.81650
# [Trian] Step: 80500, loss: 0.25000, acc: 0.75000
# [Trian] Step: 81000, loss: 0.20200, acc: 0.80000
# [Trian] Step: 81500, loss: 0.20045, acc: 0.80000
# [Trian] Step: 82000, loss: 0.25222, acc: 0.75000
# [Trian] Step: 82500, loss: 0.10550, acc: 0.90000
# [Trian] Step: 83000, loss: 0.25016, acc: 0.75000
# [Trian] Step: 83500, loss: 0.05000, acc: 0.95000
# [Trian] Step: 84000, loss: 0.20174, acc: 0.80000
# [Trian] Step: 84500, loss: 0.01396, acc: 0.95000
# [Trian] Step: 85000, loss: 0.15434, acc: 0.85000
# [Test] Step: 85000, acc: 0.81600
# [Trian] Step: 85500, loss: 0.14944, acc: 0.85000
# [Trian] Step: 86000, loss: 0.25169, acc: 0.75000
# [Trian] Step: 86500, loss: 0.25000, acc: 0.75000
# [Trian] Step: 87000, loss: 0.26087, acc: 0.70000
# [Trian] Step: 87500, loss: 0.19994, acc: 0.80000
# [Trian] Step: 88000, loss: 0.15829, acc: 0.85000
# [Trian] Step: 88500, loss: 0.15023, acc: 0.85000
# [Trian] Step: 89000, loss: 0.20116, acc: 0.80000
# [Trian] Step: 89500, loss: 0.06019, acc: 0.95000
# [Trian] Step: 90000, loss: 0.05475, acc: 0.95000
# [Test] Step: 90000, acc: 0.81700
# [Trian] Step: 90500, loss: 0.10488, acc: 0.90000
# [Trian] Step: 91000, loss: 0.19997, acc: 0.80000
# [Trian] Step: 91500, loss: 0.15000, acc: 0.85000
# [Trian] Step: 92000, loss: 0.16472, acc: 0.85000
# [Trian] Step: 92500, loss: 0.10026, acc: 0.90000
# [Trian] Step: 93000, loss: 0.05100, acc: 0.95000
# [Trian] Step: 93500, loss: 0.10415, acc: 0.90000
# [Trian] Step: 94000, loss: 0.14025, acc: 0.85000
# [Trian] Step: 94500, loss: 0.05953, acc: 0.95000
# [Trian] Step: 95000, loss: 0.20005, acc: 0.80000
# [Test] Step: 95000, acc: 0.82000
# [Trian] Step: 95500, loss: 0.10019, acc: 0.90000
# [Trian] Step: 96000, loss: 0.34508, acc: 0.65000
# [Trian] Step: 96500, loss: 0.15000, acc: 0.85000
# [Trian] Step: 97000, loss: 0.00240, acc: 1.00000
# [Trian] Step: 97500, loss: 0.00144, acc: 1.00000
# [Trian] Step: 98000, loss: 0.15004, acc: 0.85000
# [Trian] Step: 98500, loss: 0.14681, acc: 0.85000
# [Trian] Step: 99000, loss: 0.19970, acc: 0.80000
# [Trian] Step: 99500, loss: 0.10295, acc: 0.90000
# [Trian] Step: 100000, loss: 0.03018, acc: 0.95000
# [Test] Step: 100000, acc: 0.81900
